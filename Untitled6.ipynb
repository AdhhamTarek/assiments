# %%
import pandas as pd
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
mms = preprocessing.MinMaxScaler()
ohe = preprocessing.OneHotEncoder(sparse=False)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv ('/content/drive/MyDrive/used cars regression.csv')

# %%
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# ...

# %%
df['Fuel_Type'].unique()
# Out:
# array(['CNG', 'Diesel', 'Petrol', 'LPG', 'Electric'], dtype=object)

# %%
df.drop(['New_Price'], axis = 1, inplace = True)

# %%
df  = df.dropna()

# %%
df['Location'].unique()
# Out:
# array(['Mumbai', 'Pune', 'Chennai', 'Coimbatore', 'Hyderabad', 'Jaipur',
#        'Kochi', 'Kolkata', 'Delhi', 'Bangalore', 'Ahmedabad'],
#       dtype=object)

# %%
sns.boxplot(x = 'Fuel_Type' , y = 'Price' , data = df)

# %% [markdown]
# there is a lot of out layers in petrol and diesel

# %%
sns.barplot(x = 'Fuel_Type' , y = 'Price' , data = df)

# %%
sns.scatterplot(x = 'Engine' , y= 'Power' , data= df)

# %%
df['Engine'].unique()
# Out:
# array(['998 CC', '1582 CC', '1199 CC', '1248 CC', '1968 CC', '814 CC',
#        '1461 CC', '2755 CC', '1598 CC', '1462 CC', '1497 CC', '2179 CC',
#        '2477 CC', '1498 CC', '2143 CC', '1995 CC', '1984 CC', '1197 CC',
#        '2494 CC', '1798 CC', '2696 CC', '2698 CC', '1061 CC', '1198 CC',
#        '2987 CC', '796 CC', '624 CC', '1999 CC', '1991 CC', '2694 CC',
#        '1120 CC', '2498 CC', '799 CC', '2393 CC', '1399 CC', '1796 CC',
#        '2148 CC', '1396 CC', '1950 CC', '4806 CC', '1998 CC', '1086 CC',
#        '1193 CC', '2982 CC', '1493 CC', '2967 CC', '2993 CC', '1196 CC',
#        '1799 CC', '2497 CC', '2354 CC', '1373 CC', '2996 CC', '1591 CC',
#        '2894 CC', '5461 CC', '1595 CC', '936 CC', '1997 CC', '1896 CC',
#        '1390 CC', '1364 CC', '2199 CC', '993 CC', '999 CC', '1405 CC',
#        '2956 CC', '1794 CC', '995 CC', '2496 CC', '1599 CC', '2400 CC',
#        '1495 CC', '2523 CC', '793 CC', '4134 CC', '1596 CC', '1395 CC',
# ...

# %%
split_data = df["Engine"].str.split()
data = split_data.to_list()
names = ["no_of_cc", "ccc"]
new_df = pd.DataFrame(data, columns=names)

# %%
data = split_data.to_list()
names = ["no_of_cc", "ccc"]
new_df = pd.DataFrame(data, columns=names)
df.drop(['Engine'], axis = 1, inplace = True)
new_df.drop(['ccc'], axis = 1, inplace = True)
df = pd.concat([df,new_df ], axis=1, join='inner')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df['no_of_cc']=df['no_of_cc'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5931 entries, 0 to 5974
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5931 non-null   int64
#  1   Name               5931 non-null   object
#  2   Location           5931 non-null   object
#  3   Year               5931 non-null   int64
#  4   Kilometers_Driven  5931 non-null   int64
#  5   Fuel_Type          5931 non-null   object
#  6   Transmission       5931 non-null   object
#  7   Owner_Type         5931 non-null   object
#  8   Mileage            5931 non-null   object
#  9   Power              5931 non-null   object
#  10  Seats              5931 non-null   float64
#  11  Price              5931 non-null   float64
#  12  no_of_cc           5931 non-null   int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 648.7+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5931 entries, 0 to 5974
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         5931 non-null   int64
#  1   Name               5931 non-null   object
#  2   Location           5931 non-null   object
#  3   Year               5931 non-null   int64
#  4   Kilometers_Driven  5931 non-null   int64
#  5   Fuel_Type          5931 non-null   object
#  6   Transmission       5931 non-null   object
#  7   Owner_Type         5931 non-null   object
#  8   Mileage            5931 non-null   object
#  9   Power              5931 non-null   object
#  10  Seats              5931 non-null   float64
#  11  Price              5931 non-null   float64
#  12  no_of_cc           5931 non-null   object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 648.7+ KB

# %%
split_data = df["Power"].str.split()
data = split_data.to_list()
names = ["no_of_power", "ccc"]
new_df1 = pd.DataFrame(data, columns=names)
data = split_data.to_list()

df.drop(['Power'], axis = 1, inplace = True)
new_df1.drop(['ccc'], axis = 1, inplace = True)
df = pd.concat([df,new_df1], axis=1, join='inner')

# %%
df['no_of_power']=df['no_of_power'].replace('null',0)

# %%
df['no_of_power']=df['no_of_power'].astype(float)

# %%
sns.scatterplot(x = 'no_of_cc' , y= 'no_of_power' ,hue = 'Fuel_Type', data= df)

# %% [markdown]
# there is outlayers will be removed as it has null value in no_of_power and we estimate that no_of cc has high corr with no of power units released

# %%
g = sns.FacetGrid(df , col = 'Fuel_Type')
g.map_dataframe(sns.histplot,x='no_of_power',y='no_of_cc');
